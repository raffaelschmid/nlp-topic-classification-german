# %% [markdown]
# # Exploratory Data Analysis

# %%
from pandas import concat, read_parquet

from data import file
import missingno as msno
import seaborn as sns
import pandas as pd

# %%
data_train = read_parquet(file.news_articles_raw_train)
data_test = read_parquet(file.news_articles_raw_test)

# %% [markdown]
# ## Missing Data

# %% [markdown]
# For training and test dataset I am visualizing missing data using [Missingno](https://github.com/ResidentMario/missingno) library. It looks like in both datasets the texts as well as labels are already cleaned and no data is missing.

# %% [markdown]
# ### Training Set

# %%
msno.matrix(data_train)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Test Set

# %%
msno.matrix(data_test)
# Out:
# <AxesSubplot:>
